# %%
from utils import prepare_data
import numpy as np

# %%
def load_glove(file_path, small=True):
    idx = 0
    vectors = {}
    word2idx = {}
    words = []
    with open(file_path, encoding='utf8') as lines:
        for line in lines:
            if small and idx > 5000:
                break
            line = line.split()
            word2idx[line[0].lower()] = idx
            vectors[line[0].lower()] = np.array(list(line[1:]), dtype='float')
            idx += 1
    return vectors, word2idx

# %%
vec, word2idx = load_glove('glove.42B.300d/glove.42B.300d.txt')

# %%
import operator
{k: v for k, v in sorted(word2idx.items(), key=operator.itemgetter(1))}
# Out:
# {',': 0,
#  'the': 1,
#  '.': 2,
#  'and': 3,
#  'to': 4,
#  'of': 5,
#  'a': 6,
#  'in': 7,
#  '"': 8,
#  'is': 9,
#  'for': 10,
#  ':': 11,
#  'i': 12,
#  ')': 13,
#  'that': 14,
#  '(': 15,
#  'you': 16,
#  'it': 17,
#  'on': 18,
#  '-': 19,
#  'with': 20,
#  "'s": 21,
#  'this': 22,
#  'by': 23,
#  'are': 24,
#  'at': 25,
#  'as': 26,
#  'be': 27,
#  'from': 28,
#  'have': 29,
#  'was': 30,
#  'or': 31,
#  'your': 32,
#  'not': 33,
#  '...': 34,
#  'we': 35,
#  '!': 36,
#  'but': 37,
#  '?': 38,
#  'all': 39,
#  'will': 40,
#  'an': 41,
#  'my': 42,
#  'can': 43,
#  'they': 44,
#  "n't": 45,
#  'do': 46,
#  'he': 47,
#  'more': 48,
#  'if': 49,
#  'one': 50,
#  'has': 51,
#  '|': 52,
#  'so': 53,
#  'about': 54,
#  'new': 55,
#  'what': 56,
#  'his': 57,
#  'there': 58,
#  'up': 59,
#  'out': 60,
#  ';': 61,
#  'their': 62,
#  'our': 63,
#  "'": 64,
#  'like': 65,
#  'when': 66,
#  '$': 67,
#  'just': 68,
#  'time': 69,
#  '&': 70,
#  'me': 71,
#  'which': 72,
#  'who': 73,
#  'no': 74,
#  'would': 75,
#  '/': 76,
#  '1': 77,
#  'some': 78,
#  'get': 79,
#  '[': 80,
#  ']': 81,
#  'also': 82,
#  'other': 83,
#  'how': 84,
#  'may': 85,
#  'had': 86,
#  'am': 87,
#  'been': 88,
#  '2': 89,
#  'her': 90,
#  'were': 91,
#  'them': 92,
#  'people': 93,
#  'she': 94,
#  'any': 95,
#  'now': 96,
#  'only': 97,
#  'pm': 98,
#  'first': 99,
#  'than': 100,
#  'good': 101,
#  '>': 102,
#  'into': 103,
#  'its': 104,
#  'these': 105,
#  'us': 106,
#  'see': 107,
#  'here': 108,
#  'make': 109,
#  'home': 110,
#  '3': 111,
#  'very': 112,
#  'over': 113,
#  'most': 114,
#  'then': 115,
#  'know': 116,
#  'said': 117,
#  'after': 118,
#  'well': 119,
#  'use': 120,
#  'two': 121,
#  '%': 122,
#  'did': 123,
#  'could': 124,
#  'day': 125,
#  'great': 126,
#  'free': 127,
#  'many': 128,
#  'back': 129,
#  'way': 130,
#  'work': 131,
#  'because': 132,
#  "'m": 133,
#  'best': 134,
#  'should': 135,
#  'even': 136,
#  'year': 137,
#  'think': 138,
#  'years': 139,
#  'much': 140,
#  'does': 141,
#  'where': 142,
#  '4': 143,
#  'go': 144,
#  'love': 145,
#  'need': 146,
#  'last': 147,
#  'find': 148,
#  '2012': 149,
#  '=': 150,
#  'world': 151,
#  'really': 152,
#  'information': 153,
#  'through': 154,
#  'want': 155,
#  '#': 156,
#  '5': 157,
#  'him': 158,
#  'right': 159,
#  'take': 160,
#  'views': 161,
#  'such': 162,
#  'made': 163,
#  'those': 164,
#  'business': 165,
#  'life': 166,
#  '2011': 167,
#  'before': 168,
#  'being': 169,
#  '--': 170,
#  'off': 171,
#  'used': 172,
#  'help': 173,
#  '10': 174,
#  'while': 175,
#  'posted': 176,
#  "'re": 177,
#  'too': 178,
#  'still': 179,
#  "'ve": 180,
#  'down': 181,
#  '2010': 182,
#  'going': 183,
#  'video': 184,
#  'part': 185,
#  'online': 186,
#  'each': 187,
#  'little': 188,
#  'high': 189,
#  '+': 190,
#  'look': 191,
#  'around': 192,
#  'same': 193,
#  'game': 194,
#  'read': 195,
#  'service': 196,
#  '2009': 197,
#  'long': 198,
#  'why': 199,
#  'school': 200,
#  'state': 201,
#  '6': 202,
#  'post': 203,
#  'city': 204,
#  'own': 205,
#  'every': 206,
#  'system': 207,
#  'next': 208,
#  "'ll": 209,
#  'news': 210,
#  'site': 211,
#  'say': 212,
#  'got': 213,
#  'both': 214,
#  'under': 215,
#  'top': 216,
#  'set': 217,
#  'another': 218,
#  'since': 219,
#  'things': 220,
#  'available': 221,
#  'show': 222,
#  'place': 223,
#  'using': 224,
#  'better': 225,
#  'page': 226,
#  'never': 227,
#  'please': 228,
#  'come': 229,
#  'big': 230,
#  'today': 231,
#  's': 232,
#  'family': 233,
#  'music': 234,
#  'services': 235,
#  'full': 236,
#  'something': 237,
#  'number': 238,
#  'company': 239,
#  'few': 240,
#  '7': 241,
#  'price': 242,
#  'ca': 243,
#  'between': 244,
#  'days': 245,
#  'book': 246,
#  '0': 247,
#  'name': 248,
#  'view': 249,
#  'found': 250,
#  'ago': 251,
#  'real': 252,
#  'without': 253,
#  'old': 254,
#  'search': 255,
#  'always': 256,
#  'black': 257,
#  'house': 258,
#  '2008': 259,
#  'three': 260,
#  '8': 261,
#  'man': 262,
#  'must': 263,
#  'during': 264,
#  'again': 265,
#  'end': 266,
#  '12': 267,
#  'different': 268,
#  'lot': 269,
#  'health': 270,
#  'looking': 271,
#  'week': 272,
#  'sure': 273,
#  'group': 274,
#  'give': 275,
#  '20': 276,
#  'team': 277,
#  'power': 278,
#  'times': 279,
#  'let': 280,
#  'car': 281,
#  'area': 282,
#  'buy': 283,
#  'money': 284,
#  'water': 285,
#  'keep': 286,
#  'support': 287,
#  'web': 288,
#  'data': 289,
#  'live': 290,
#  'comments': 291,
#  'small': 292,
#  '.....': 293,
#  'play': 294,
#  'including': 295,
#  'x': 296,
#  'thing': 297,
#  'list': 298,
#  'put': 299,
#  'children': 300,
#  'design': 301,
#  'women': 302,
#  'might': 303,
#  'white': 304,
#  'public': 305,
#  'point': 306,
#  'order': 307,
#  '2013': 308,
#  'call': 309,
#  'second': 310,
#  'local': 311,
#  'says': 312,
#  'case': 313,
#  'care': 314,
#  'download': 315,
#  'reblogged': 316,
#  'program': 317,
#  '....': 318,
#  'night': 319,
#  '15': 320,
#  'blog': 321,
#  'away': 322,
#  'start': 323,
#  'products': 324,
#  'review': 325,
#  'against': 326,
#  'left': 327,
#  'however': 328,
#  'center': 329,
#  'feel': 330,
#  'having': 331,
#  '11': 332,
#  'website': 333,
#  'line': 334,
#  'thanks': 335,
#  'food': 336,
#  'ever': 337,
#  '9': 338,
#  'open': 339,
#  'university': 340,
#  'room': 341,
#  'though': 342,
#  '30': 343,
#  'god': 344,
#  'product': 345,
#  'national': 346,
#  'change': 347,
#  'making': 348,
#  'experience': 349,
#  'add': 350,
#  '2007': 351,
#  'internet': 352,
#  'hotel': 353,
#  'check': 354,
#  'job': 355,
#  'getting': 356,
#  'date': 357,
#  "'d": 358,
#  'quality': 359,
#  'once': 360,
#  'course': 361,
#  'american': 362,
#  'hard': 363,
#  'within': 364,
#  'contact': 365,
#  'until': 366,
#  'try': 367,
#  'sale': 368,
#  'games': 369,
#  'side': 370,
#  'able': 371,
#  'county': 372,
#  'phone': 373,
#  'research': 374,
#  'community': 375,
#  'software': 376,
#  'working': 377,
#  'march': 378,
#  'art': 379,
#  'yet': 380,
#  'months': 381,
#  'body': 382,
#  'easy': 383,
#  'control': 384,
#  'story': 385,
#  'done': 386,
#  'light': 387,
#  'de': 388,
#  'click': 389,
#  'country': 390,
#  'provide': 391,
#  'market': 392,
#  'results': 393,
#  'large': 394,
#  'person': 395,
#  'actually': 396,
#  'less': 397,
#  'office': 398,
#  'enough': 399,
#  'men': 400,
#  'government': 401,
#  'june': 402,
#  'following': 403,
#  'special': 404,
#  'international': 405,
#  'states': 406,
#  'report': 407,
#  'makes': 408,
#  'per': 409,
#  'important': 410,
#  'united': 411,
#  'series': 412,
#  'april': 413,
#  'doing': 414,
#  'size': 415,
#  'air': 416,
#  'hours': 417,
#  'red': 418,
#  'john': 419,
#  'south': 420,
#  'project': 421,
#  'thought': 422,
#  'nice': 423,
#  'management': 424,
#  'based': 425,
#  'run': 426,
#  'development': 427,
#  '100': 428,
#  'type': 429,
#  'history': 430,
#  'least': 431,
#  'friends': 432,
#  '18': 433,
#  '14': 434,
#  '13': 435,
#  'email': 436,
#  'party': 437,
#  'general': 438,
#  'north': 439,
#  '16': 440,
#  'law': 441,
#  'bad': 442,
#  'far': 443,
#  '25': 444,
#  'head': 445,
#  'problem': 446,
#  'already': 447,
#  'called': 448,
#  'process': 449,
#  'january': 450,
#  'fun': 451,
#  'york': 452,
#  'someone': 453,
#  'hope': 454,
#  'students': 455,
#  'watch': 456,
#  'hot': 457,
#  'photo': 458,
#  'level': 459,
#  'movie': 460,
#  'comment': 461,
#  'july': 462,
#  'media': 463,
#  'together': 464,
#  'needs': 465,
#  '!!': 466,
#  'others': 467,
#  '24': 468,
#  'include': 469,
#  'young': 470,
#  'season': 471,
#  'members': 472,
#  'version': 473,
#  'started': 474,
#  'offer': 475,
#  'went': 476,
#  'form': 477,
#  'anything': 478,
#  'several': 479,
#  'file': 480,
#  'bit': 481,
#  'road': 482,
#  'tell': 483,
#  '@': 484,
#  'link': 485,
#  'article': 486,
#  'pretty': 487,
#  'often': 488,
#  'four': 489,
#  'february': 490,
#  'park': 491,
#  'tv': 492,
#  'came': 493,
#  'hand': 494,
#  'yes': 495,
#  'everything': 496,
#  'green': 497,
#  'share': 498,
#  'access': 499,
#  'social': 500,
#  'fact': 501,
#  'reviews': 502,
#  'personal': 503,
#  'visit': 504,
#  'single': 505,
#  'along': 506,
#  'become': 507,
#  '~': 508,
#  'points': 509,
#  'plan': 510,
#  'added': 511,
#  'october': 512,
#  'reply': 513,
#  'believe': 514,
#  'technology': 515,
#  '2006': 516,
#  'possible': 517,
#  'photos': 518,
#  'street': 519,
#  'everyone': 520,
#  'past': 521,
#  'anyone': 522,
#  'below': 523,
#  'features': 524,
#  'means': 525,
#  'west': 526,
#  'windows': 527,
#  'current': 528,
#  'related': 529,
#  'september': 530,
#  'details': 531,
#  'november': 532,
#  'code': 533,
#  'sex': 534,
#  'tags': 535,
#  'college': 536,
#  'nothing': 537,
#  'class': 538,
#  'event': 539,
#  'card': 540,
#  '17': 541,
#  'seen': 542,
#  'december': 543,
#  're': 544,
#  'minutes': 545,
#  'august': 546,
#  'value': 547,
#  'training': 548,
#  'beautiful': 549,
#  'early': 550,
#  'took': 551,
#  'security': 552,
#  'true': 553,
#  'education': 554,
#  'comes': 555,
#  'kind': 556,
#  'source': 557,
#  'song': 558,
#  'board': 559,
#  'film': 560,
#  'learn': 561,
#  'low': 562,
#  'happy': 563,
#  'question': 564,
#  'front': 565,
#  'kids': 566,
#  'property': 567,
#  'reading': 568,
#  'probably': 569,
#  'short': 570,
#  'above': 571,
#  'create': 572,
#  'computer': 573,
#  'whole': 574,
#  'blue': 575,
#  'either': 576,
#  'given': 577,
#  'example': 578,
#  'heart': 579,
#  '£': 580,
#  'near': 581,
#  'parts': 582,
#  'member': 583,
#  'future': 584,
#  'whether': 585,
#  'building': 586,
#  'insurance': 587,
#  'girl': 588,
#  'c': 589,
#  '21': 590,
#  'energy': 591,
#  '19': 592,
#  'image': 593,
#  'million': 594,
#  'child': 595,
#  'face': 596,
#  'maybe': 597,
#  'pay': 598,
#  'mind': 599,
#  'thank': 600,
#  'close': 601,
#  'books': 602,
#  '22': 603,
#  'complete': 604,
#  'network': 605,
#  'main': 606,
#  'u.s.': 607,
#  'trying': 608,
#  'war': 609,
#  'location': 610,
#  'later': 611,
#  'user': 612,
#  'offers': 613,
#  'month': 614,
#  'credit': 615,
#  'president': 616,
#  'save': 617,
#  'idea': 618,
#  'human': 619,
#  'jobs': 620,
#  'words': 621,
#  'works': 622,
#  'travel': 623,
#  'perfect': 624,
#  'total': 625,
#  'cost': 626,
#  'store': 627,
#  'looks': 628,
#  'questions': 629,
#  'almost': 630,
#  'original': 631,
#  'model': 632,
#  'style': 633,
#  'systems': 634,
#  'medical': 635,
#  'space': 636,
#  'action': 637,
#  'sales': 638,
#  'taking': 639,
#  'quite': 640,
#  'age': 641,
#  '50': 642,
#  'club': 643,
#  'living': 644,
#  'known': 645,
#  'stop': 646,
#  'posts': 647,
#  'oh': 648,
#  '\\': 649,
#  'drive': 650,
#  'talk': 651,
#  'box': 652,
#  'events': 653,
#  'color': 654,
#  'content': 655,
#  'study': 656,
#  'companies': 657,
#  'via': 658,
#  'baby': 659,
#  '!!!': 660,
#  'church': 661,
#  'b': 662,
#  'natural': 663,
#  'issue': 664,
#  'coming': 665,
#  'test': 666,
#  'major': 667,
#  'five': 668,
#  'performance': 669,
#  'industry': 670,
#  'mean': 671,
#  'america': 672,
#  'key': 673,
#  'uk': 674,
#  'enjoy': 675,
#  'collection': 676,
#  'range': 677,
#  'rate': 678,
#  'marketing': 679,
#  'told': 680,
#  'simple': 681,
#  '23': 682,
#  'seems': 683,
#  'digital': 684,
#  'ask': 685,
#  'rights': 686,
#  'court': 687,
#  'due': 688,
#  'sound': 689,
#  'friend': 690,
#  'send': 691,
#  'across': 692,
#  'word': 693,
#  '2005': 694,
#  'remember': 695,
#  'leave': 696,
#  'according': 697,
#  'professional': 698,
#  'soon': 699,
#  'wanted': 700,
#  'problems': 701,
#  'miles': 702,
#  'else': 703,
#  'private': 704,
#  'includes': 705,
#  'english': 706,
#  'field': 707,
#  'rather': 708,
#  'cover': 709,
#  'beach': 710,
#  'issues': 711,
#  'stay': 712,
#  'taken': 713,
#  'message': 714,
#  'girls': 715,
#  'reason': 716,
#  '>>': 717,
#  'pictures': 718,
#  'address': 719,
#  'financial': 720,
#  'turn': 721,
#  'guide': 722,
#  'although': 723,
#  'especially': 724,
#  'move': 725,
#  'oil': 726,
#  'prices': 727,
#  'half': 728,
#  'star': 729,
#  'simply': 730,
#  'press': 731,
#  'estate': 732,
#  'continue': 733,
#  'running': 734,
#  'section': 735,
#  'woman': 736,
#  'weeks': 737,
#  'policy': 738,
#  'latest': 739,
#  'return': 740,
#  '26': 741,
#  'la': 742,
#  'department': 743,
#  'shows': 744,
#  'stock': 745,
#  '28': 746,
#  'title': 747,
#  'summer': 748,
#  'provides': 749,
#  'picture': 750,
#  'deal': 751,
#  'note': 752,
#  'm': 753,
#  'win': 754,
#  'paper': 755,
#  'town': 756,
#  'meet': 757,
#  'mobile': 758,
#  'items': 759,
#  'hair': 760,
#  'understand': 761,
#  ':)': 762,
#  'friday': 763,
#  'further': 764,
#  'weight': 765,
#  'follow': 766,
#  'application': 767,
#  't': 768,
#  'account': 769,
#  'asked': 770,
#  'plus': 771,
#  'staff': 772,
#  'item': 773,
#  'death': 774,
#  'bring': 775,
#  'sports': 776,
#  'player': 777,
#  'lost': 778,
#  'google': 779,
#  '_': 780,
#  'published': 781,
#  'gold': 782,
#  'london': 783,
#  'gets': 784,
#  'act': 785,
#  'among': 786,
#  'shop': 787,
#  'east': 788,
#  'upon': 789,
#  'guy': 790,
#  '27': 791,
#  'wedding': 792,
#  'subject': 793,
#  'd': 794,
#  'instead': 795,
#  'morning': 796,
#  'videos': 797,
#  'usually': 798,
#  'clear': 799,
#  'science': 800,
#  'couple': 801,
#  'playing': 802,
#  'standard': 803,
#  'present': 804,
#  'recent': 805,
#  'san': 806,
#  'david': 807,
#  'lyrics': 808,
#  'release': 809,
#  'currently': 810,
#  'table': 811,
#  'etc.': 812,
#  'daily': 813,
#  'record': 814,
#  'stuff': 815,
#  'matter': 816,
#  'required': 817,
#  'fire': 818,
#  'inside': 819,
#  'needed': 820,
#  'sun': 821,
#  'writing': 822,
#  'favorite': 823,
#  'final': 824,
#  'various': 825,
#  'behind': 826,
#  'third': 827,
#  'dog': 828,
#  'common': 829,
#  'provided': 830,
#  'u': 831,
#  'saw': 832,
#  'cool': 833,
#  'guys': 834,
#  'california': 835,
#  'popular': 836,
#  'tax': 837,
#  'interest': 838,
#  'located': 839,
#  'meeting': 840,
#  'rock': 841,
#  'takes': 842,
#  'cheap': 843,
#  'fast': 844,
#  'choose': 845,
#  'position': 846,
#  'links': 847,
#  'similar': 848,
#  'name@domain.com': 849,
#  'hit': 850,
#  'forum': 851,
#  'write': 852,
#  'cut': 853,
#  '29': 854,
#  'n': 855,
#  'written': 856,
#  'users': 857,
#  'areas': 858,
#  'info': 859,
#  'sites': 860,
#  'sunday': 861,
#  'created': 862,
#  'result': 863,
#  'amazing': 864,
#  'yourself': 865,
#  'lead': 866,
#  'treatment': 867,
#  'saturday': 868,
#  'cannot': 869,
#  'wo': 870,
#  'terms': 871,
#  'pages': 872,
#  'bill': 873,
#  'land': 874,
#  'e': 875,
#  'fine': 876,
#  'cause': 877,
#  'designed': 878,
#  'resources': 879,
#  'images': 880,
#  'rest': 881,
#  'goes': 882,
#  'wrong': 883,
#  'outside': 884,
#  'band': 885,
#  'ready': 886,
#  'sometimes': 887,
#  'author': 888,
#  'amount': 889,
#  'text': 890,
#  'sign': 891,
#  '2004': 892,
#  'customer': 893,
#  'mr.': 894,
#  'police': 895,
#  'changes': 896,
#  'players': 897,
#  'join': 898,
#  'equipment': 899,
#  'longer': 900,
#  'usa': 901,
#  'recently': 902,
#  'finally': 903,
#  'central': 904,
#  'student': 905,
#  'myself': 906,
#  'bank': 907,
#  'choice': 908,
#  'previous': 909,
#  'percent': 910,
#  'programs': 911,
#  'hotels': 912,
#  'map': 913,
#  'step': 914,
#  'w': 915,
#  'washington': 916,
#  'interesting': 917,
#  'strong': 918,
#  'ways': 919,
#  'late': 920,
#  'customers': 921,
#  'director': 922,
#  'global': 923,
#  'period': 924,
#  'mark': 925,
#  'category': 926,
#  '{': 927,
#  'welcome': 928,
#  'mother': 929,
#  'bar': 930,
#  'hear': 931,
#  'homes': 932,
#  'held': 933,
#  'shall': 934,
#  'movies': 935,
#  'received': 936,
#  'king': 937,
#  'unique': 938,
#  'forward': 939,
#  'description': 940,
#  'door': 941,
#  'answer': 942,
#  'jan': 943,
#  'christmas': 944,
#  'tools': 945,
#  'james': 946,
#  'worth': 947,
#  'certain': 948,
#  'additional': 949,
#  'fall': 950,
#  'safety': 951,
#  'wall': 952,
#  'heard': 953,
#  'gift': 954,
#  'bed': 955,
#  'material': 956,
#  'excellent': 957,
#  'st.': 958,
#  'practice': 959,
#  'conference': 960,
#  'inc.': 961,
#  'language': 962,
#  'brand': 963,
#  'speed': 964,
#  'wish': 965,
#  'wait': 966,
#  'obama': 967,
#  'included': 968,
#  'build': 969,
#  'sense': 970,
#  'monday': 971,
#  'track': 972,
#  'lol': 973,
#  'learning': 974,
#  'saying': 975,
#  'skin': 976,
#  'loss': 977,
#  'quote': 978,
#  'lake': 979,
#  'huge': 980,
#  'production': 981,
#  'thinking': 982,
#  'six': 983,
#  'album': 984,
#  'brown': 985,
#  'radio': 986,
#  'super': 987,
#  'china': 988,
#  'likely': 989,
#  'society': 990,
#  'eyes': 991,
#  'update': 992,
#  'options': 993,
#  '40': 994,
#  'son': 995,
#  'screen': 996,
#  'engine': 997,
#  'wrote': 998,
#  'paul': 999,
#  ...}

# %%
word2idx.keys()
# Out:
# dict_keys([',', 'the', '.', 'and', 'to', 'of', 'a', 'in', '"', 'is', 'for', ':', 'i', ')', 'that', '(', 'you', 'it', 'on', '-', 'with', "'s", 'this', 'by', 'are', 'at', 'as', 'be', 'from', 'have', 'was', 'or', 'your', 'not', '...', 'we', '!', 'but', '?', 'all', 'will', 'an', 'my', 'can', 'they', "n't", 'do', 'he', 'more', 'if', 'one', 'has', '|', 'so', 'about', 'new', 'what', 'his', 'there', 'up', 'out', ';', 'their', 'our', "'", 'like', 'when', '$', 'just', 'time', '&', 'me', 'which', 'who', 'no', 'would', '/', '1', 'some', 'get', '[', ']', 'also', 'other', 'how', 'may', 'had', 'am', 'been', '2', 'her', 'were', 'them', 'people', 'she', 'any', 'now', 'only', 'pm', 'first', 'than', 'good', '>', 'into', 'its', 'these', 'us', 'see', 'here', 'make', 'home', '3', 'very', 'over', 'most', 'then', 'know', 'said', 'after', 'well', 'use', 'two', '%', 'did', 'could', 'day', 'great', 'free', 'many', 'back', 'way', 'work', 'because', "'m", 'best', 'should', 'even', 'year', 'think', 'years', 'much', 'does', 'where', '4', 'go', 'love', 'need', 'last', 'find', '2012', '=', 'world', 'really', 'information', 'through', 'want', '#', '5', 'him', 'right', 'take', 'views', 'such', 'made', 'those', 'business', 'life', '2011', 'before', 'being', '--', 'off', 'used', 'help', '10', 'while', 'posted', "'re", 'too', 'still', "'ve", 'down', '2010', 'going', 'video', 'part', 'online', 'each', 'little', 'high', '+', 'look', 'around', 'same', 'game', 'read', 'service', '2009', 'long', 'why', 'school', 'state', '6', 'post', 'city', 'own', 'every', 'system', 'next', "'ll", 'news', 'site', 'say', 'got', 'both', 'under', 'top', 'set', 'another', 'since', 'things', 'available', 'show', 'place', 'using', 'better', 'page', 'never', 'please', 'come', 'big', 'today', 's', 'family', 'music', 'services', 'full', 'something', 'number', 'company', 'few', '7', 'price', 'ca', 'between', 'days', 'book', '0', 'name', 'view', 'found', 'ago', 'real', 'without', 'old', 'search', 'always', 'black', 'house', '2008', 'three', '8', 'man', 'must', 'during', 'again', 'end', '12', 'different', 'lot', 'health', 'looking', 'week', 'sure', 'group', 'give', '20', 'team', 'power', 'times', 'let', 'car', 'area', 'buy', 'money', 'water', 'keep', 'support', 'web', 'data', 'live', 'comments', 'small', '.....', 'play', 'including', 'x', 'thing', 'list', 'put', 'children', 'design', 'women', 'might', 'white', 'public', 'point', 'order', '2013', 'call', 'second', 'local', 'says', 'case', 'care', 'download', 'reblogged', 'program', '....', 'night', '15', 'blog', 'away', 'start', 'products', 'review', 'against', 'left', 'however', 'center', 'feel', 'having', '11', 'website', 'line', 'thanks', 'food', 'ever', '9', 'open', 'university', 'room', 'though', '30', 'god', 'product', 'national', 'change', 'making', 'experience', 'add', '2007', 'internet', 'hotel', 'check', 'job', 'getting', 'date', "'d", 'quality', 'once', 'course', 'american', 'hard', 'within', 'contact', 'until', 'try', 'sale', 'games', 'side', 'able', 'county', 'phone', 'research', 'community', 'software', 'working', 'march', 'art', 'yet', 'months', 'body', 'easy', 'control', 'story', 'done', 'light', 'de', 'click', 'country', 'provide', 'market', 'results', 'large', 'person', 'actually', 'less', 'office', 'enough', 'men', 'government', 'june', 'following', 'special', 'international', 'states', 'report', 'makes', 'per', 'important', 'united', 'series', 'april', 'doing', 'size', 'air', 'hours', 'red', 'john', 'south', 'project', 'thought', 'nice', 'management', 'based', 'run', 'development', '100', 'type', 'history', 'least', 'friends', '18', '14', '13', 'email', 'party', 'general', 'north', '16', 'law', 'bad', 'far', '25', 'head', 'problem', 'already', 'called', 'process', 'january', 'fun', 'york', 'someone', 'hope', 'students', 'watch', 'hot', 'photo', 'level', 'movie', 'comment', 'july', 'media', 'together', 'needs', '!!', 'others', '24', 'include', 'young', 'season', 'members', 'version', 'started', 'offer', 'went', 'form', 'anything ...

# %%
q, a, pairs = prepare_data('test', 'glove.42B.300d/glove.42B.300d.txt')
# Out:
# Reading test -------
# Read 4041 sentence pairs
# Counting words
# Counted words:
# In questions: 5087 words
# In answers: 394 words
